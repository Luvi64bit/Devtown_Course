# %% [markdown]
# <a href="https://colab.research.google.com/github/Luvi64bit/Devtown_Course/blob/main/ENSEMBLE_LEARNING_AND_RANDOMFOREST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

# %%
df = pd.read_csv("/content/CarPrice_Assignment.csv")

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# ...

# %%
df.shape
# Out:
# (205, 26)

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df.columns
# Out:
# Index(['car_ID', 'symboling', 'CarName', 'fueltype', 'aspiration',
#        'doornumber', 'carbody', 'drivewheel', 'enginelocation', 'wheelbase',
#        'carlength', 'carwidth', 'carheight', 'curbweight', 'enginetype',
#        'cylindernumber', 'enginesize', 'fuelsystem', 'boreratio', 'stroke',
#        'compressionratio', 'horsepower', 'peakrpm', 'citympg', 'highwaympg',
#        'price'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
# ...

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# ...

# %%
df.isna().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
df.CarName.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
df.CarName.nunique()
# Out:
# 147

# %%
df['CarName'] = df['CarName'].apply(lambda x: x.split()[0])

# %%
df.CarName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'Nissan', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
df.CarName.replace(
    ['Nissan', 'porcshce', 'toyouta', 'vokswagen', 'vw', 'maxda'],
    ['nissan', 'porsche', 'toyota', 'volkswagen', 'volkswagen', 'mazda'],
    inplace=True
)

# %%
df.CarName.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df.CarName.value_counts()
# Out:
# toyota         32
# nissan         18
# mazda          17
# mitsubishi     13
# honda          13
# volkswagen     12
# subaru         12
# peugeot        11
# volvo          11
# dodge           9
# buick           8
# bmw             8
# audi            7
# plymouth        7
# saab            6
# porsche         5
# isuzu           4
# jaguar          3
# chevrolet       3
# alfa-romero     3
# renault         2
# mercury         1
# Name: CarName, dtype: int64

# %%
arr = df.CarName.value_counts()

def new_cate(data):
  if data in arr[arr<=10]:
    return 'other'
  else:
    return data

df.CarName = df.CarName.apply(new_cate)

# %%
df.CarName.unique()
# Out:
# array(['other', 'honda', 'mazda', 'mitsubishi', 'nissan', 'peugeot',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
df.CarName.replace(
    df.CarName.unique(),
    [i for i in range(len(df.CarName.unique()))],
    inplace=True
)

# %%
df.CarName.value_counts()
# Out:
# 0    66
# 7    32
# 4    18
# 2    17
# 1    13
# 3    13
# 6    12
# 8    12
# 5    11
# 9    11
# Name: CarName, dtype: int64

# %%
df.head(2)
# Out:
#    car_ID  symboling  CarName fueltype aspiration doornumber      carbody  \
# 0       1          3        0      gas        std        two  convertible
# 1       2          3        0      gas        std        two  convertible
#
#   drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 0        rwd          front       88.6  ...         130        mpfi
# 1        rwd          front       88.6  ...         130        mpfi
#
#    boreratio  stroke compressionratio horsepower  peakrpm citympg  highwaympg  \
# 0       3.47    2.68              9.0        111     5000      21          27
# 1       3.47    2.68              9.0        111     5000      21          27
#
#      price
# 0  13495.0
# 1  16500.0
#
# [2 rows x 26 columns]

# %%
df.drop('car_ID', axis=1, inplace=True)

# %%
df.head(2)
# Out:
#    symboling  CarName fueltype aspiration doornumber      carbody drivewheel  \
# 0          3        0      gas        std        two  convertible        rwd
# 1          3        0      gas        std        two  convertible        rwd
#
#   enginelocation  wheelbase  carlength  ...  enginesize  fuelsystem  \
# 0          front       88.6      168.8  ...         130        mpfi
# 1          front       88.6      168.8  ...         130        mpfi
#
#    boreratio stroke compressionratio  horsepower peakrpm  citympg  highwaympg  \
# 0       3.47   2.68              9.0         111    5000       21          27
# 1       3.47   2.68              9.0         111    5000       21          27
#
#      price
# 0  13495.0
# 1  16500.0
#
# [2 rows x 25 columns]

# %%
df.symboling.value_counts()
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64

# %%
df.fueltype.value_counts()
# Out:
# gas       185
# diesel     20
# Name: fueltype, dtype: int64

# %%
df.aspiration.value_counts()
# Out:
# std      168
# turbo     37
# Name: aspiration, dtype: int64

# %%
df.doornumber.value_counts()
# Out:
# four    115
# two      90
# Name: doornumber, dtype: int64

# %%
df.fueltype.replace(df.fueltype.unique(),
                    [0,1],
                    inplace=True)

# %%
df.aspiration.replace(df.aspiration.unique(),
                    [0,1],
                    inplace=True)

# %%
df.doornumber.replace(df.doornumber.unique(),[2,4],inplace=True
                    )

# %%
df.carbody.value_counts()
# Out:
# sedan          96
# hatchback      70
# wagon          25
# hardtop         8
# convertible     6
# Name: carbody, dtype: int64

# %%
df.carbody.replace(df.carbody.unique(),
                    [0,1,2,3,4],
                    inplace=True)

# %%
df.drivewheel.value_counts()
# Out:
# fwd    120
# rwd     76
# 4wd      9
# Name: drivewheel, dtype: int64

# %%
df.drivewheel.replace(df.drivewheel.unique(),
                    [0,1,2],
                    inplace=True)

# %%
df.enginelocation.value_counts()
# Out:
# front    202
# rear       3
# Name: enginelocation, dtype: int64

# %%
df.enginelocation.replace(df.enginelocation.unique(),
                    [0,1],
                    inplace=True)

# %%
df.columns
# Out:
# Index(['symboling', 'CarName', 'fueltype', 'aspiration', 'doornumber',
#        'carbody', 'drivewheel', 'enginelocation', 'wheelbase', 'carlength',
#        'carwidth', 'carheight', 'curbweight', 'enginetype', 'cylindernumber',
#        'enginesize', 'fuelsystem', 'boreratio', 'stroke', 'compressionratio',
#        'horsepower', 'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# symboling             int64
# CarName               int64
# fueltype              int64
# aspiration            int64
# doornumber            int64
# carbody               int64
# drivewheel            int64
# enginelocation        int64
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
df.enginetype.value_counts()
# Out:
# ohc      148
# ohcf      15
# ohcv      13
# dohc      12
# l         12
# rotor      4
# dohcv      1
# Name: enginetype, dtype: int64

# %%
df.enginetype.replace(df.enginetype.unique(),
                    [i for i in range(len(df.enginetype.unique()))],
                    inplace=True)

# %%
df.cylindernumber.value_counts()
# Out:
# four      159
# six        24
# five       11
# eight       5
# two         4
# three       1
# twelve      1
# Name: cylindernumber, dtype: int64

# %%
df.cylindernumber.replace(['four', 'six', 'five', 'eight', 'two', 'three', 'twelve'],
                    [4,6,5,8,2,3,12],
                    inplace=True)

# %%
df.fuelsystem.value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# mfi      1
# spfi     1
# Name: fuelsystem, dtype: int64

# %%
df.fuelsystem.replace(df.fuelsystem.unique(),
                    [i for i in range(len(df.fuelsystem.unique()))],
                    inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   CarName           205 non-null    int64
#  2   fueltype          205 non-null    int64
#  3   aspiration        205 non-null    int64
#  4   doornumber        205 non-null    int64
#  5   carbody           205 non-null    int64
#  6   drivewheel        205 non-null    int64
#  7   enginelocation    205 non-null    int64
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    int64
#  14  cylindernumber    205 non-null    int64
#  15  enginesize        205 non-null    int64
# ...

# %%
df.corr()
# Out:
#                   symboling   CarName  fueltype  aspiration  doornumber  \
# symboling          1.000000 -0.252842 -0.194311   -0.059866   -0.664073
# CarName           -0.252842  1.000000  0.138434    0.020034    0.226678
# fueltype          -0.194311  0.138434  1.000000    0.401397    0.191491
# aspiration        -0.059866  0.020034  0.401397    1.000000    0.031792
# doornumber        -0.664073  0.226678  0.191491    0.031792    1.000000
# carbody           -0.398970  0.154844  0.157580    0.021276    0.447534
# drivewheel         0.041671 -0.005379 -0.132257   -0.066465    0.098954
# enginelocation     0.212471 -0.133909 -0.040070   -0.057191   -0.137757
# wheelbase         -0.531954  0.125722  0.308346    0.257611    0.447357
# carlength         -0.357612  0.084858  0.212679    0.234539    0.398568
# carwidth          -0.232919 -0.040111  0.233880    0.300567    0.207168
# carheight         -0.541038  0.279363  0.284631    0.087311    0.552208
# ...

# %%
plt.figure(figsize=(50,50))
sns.heatmap(df.corr(), annot=True, cmap='Greens')
# Out:
# <Axes: >

# %%
X = df.drop('price', axis=1)
y = df.price

# %%
X
# Out:
#      symboling  CarName  fueltype  aspiration  doornumber  carbody  \
# 0            3        0         0           0           2        0
# 1            3        0         0           0           2        0
# 2            1        0         0           0           2        1
# 3            2        0         0           0           4        2
# 4            2        0         0           0           4        2
# ..         ...      ...       ...         ...         ...      ...
# 200         -1        9         0           0           4        2
# 201         -1        9         0           1           4        2
# 202         -1        9         0           0           4        2
# 203         -1        9         1           1           4        2
# 204         -1        9         0           1           4        2
#
#      drivewheel  enginelocation  wheelbase  carlength  ...  cylindernumber  \
# 0             0               0       88.6      168.8  ...               4
# ...

# %%
model = ExtraTreesRegressor()

# %%
model.fit(X,y)
# Out:
# ExtraTreesRegressor()

# %%
model.feature_importances_
# Out:
# array([0.0025804 , 0.04091491, 0.00305847, 0.01099685, 0.00236865,
#        0.00503125, 0.07221798, 0.01399733, 0.01894669, 0.01950452,
#        0.05669235, 0.00507518, 0.14557155, 0.00453494, 0.07533453,
#        0.2229046 , 0.00778824, 0.01046621, 0.00433126, 0.00474584,
#        0.12256834, 0.01464996, 0.06544154, 0.07027842])

# %%
importance_features = pd.Series(model.feature_importances_,
                                index = X.columns)

# %%
importance_features
# Out:
# symboling           0.002580
# CarName             0.040915
# fueltype            0.003058
# aspiration          0.010997
# doornumber          0.002369
# carbody             0.005031
# drivewheel          0.072218
# enginelocation      0.013997
# wheelbase           0.018947
# carlength           0.019505
# carwidth            0.056692
# carheight           0.005075
# curbweight          0.145572
# enginetype          0.004535
# cylindernumber      0.075335
# enginesize          0.222905
# fuelsystem          0.007788
# boreratio           0.010466
# stroke              0.004331
# compressionratio    0.004746
# horsepower          0.122568
# peakrpm             0.014650
# citympg             0.065442
# highwaympg          0.070278
# dtype: float64

# %%
importance_features.nlargest(20).plot(kind='barh')
# Out:
# <Axes: >

# %%
var = importance_features.nlargest(10).index

# %%
var
# Out:
# Index(['enginesize', 'curbweight', 'horsepower', 'cylindernumber',
#        'drivewheel', 'highwaympg', 'citympg', 'carwidth', 'CarName',
#        'carlength'],
#       dtype='object')

# %%
X[list(var)]
# Out:
#      enginesize  curbweight  horsepower  cylindernumber  drivewheel  \
# 0           130        2548         111               4           0
# 1           130        2548         111               4           0
# 2           152        2823         154               6           0
# 3           109        2337         102               4           1
# 4           136        2824         115               5           2
# ..          ...         ...         ...             ...         ...
# 200         141        2952         114               4           0
# 201         141        3049         160               4           0
# 202         173        3012         134               6           0
# 203         145        3217         106               6           0
# 204         141        3062         114               4           0
#
#      highwaympg  citympg  carwidth  CarName  carlength
# 0            27       21      64.1        0      168.8
# ...

# %%
X = X[list(var)]

# %% [markdown]
# # **Choosing Appropriate Model**

# %%
model = RandomForestRegressor()

# %% [markdown]
# 1. Perfcorming the Hyper Parameter Tuning to get the best parametric value for the model using RandmoizedSearchCV

# %%
# No. of trees in a Random Forest
n_estimators = [i for i in range(100, 1201, 100)]

# No. of features to consider at every split
max_features = ['sqrt', 1.0]

# Maximum no. of levels in a Tree
max_depth = [int(i) for i in np.linspace(start=5, stop=30, num=6)]

# Minimum no. of samples required to split a node
min_samples_split = [2,5,10,15,100]

# Minimum no. of samples required at each leaf node
min_samples_leaf = [1,2,5,10]

# %%
random_grid = {
    "n_estimators": n_estimators,
    "max_features": max_features,
    "max_depth": max_depth,
    "min_samples_split": min_samples_split,
    "min_samples_leaf": min_samples_leaf
}

# %%
random_grid
# Out:
# {'n_estimators': [100,
#   200,
#   300,
#   400,
#   500,
#   600,
#   700,
#   800,
#   900,
#   1000,
#   1100,
#   1200],
#  'max_features': ['sqrt', 1.0],
#  'max_depth': [5, 10, 15, 20, 25, 30],
#  'min_samples_split': [2, 5, 10, 15, 100],
#  'min_samples_leaf': [1, 2, 5, 10]}

# %%
rf_random = RandomizedSearchCV(
    estimator = model,
    param_distributions = random_grid,
    n_jobs = 1,
    random_state = 42,
    verbose = 3,
    cv = 5
)

# %% [markdown]
# # Splitting the dataset into Training & Testing Sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.15, random_state=42)

# %%
len(X_train)
# Out:
# 174

# %%
len(X_test)
# Out:
# 31

# %% [markdown]
# # Training the model

# %%
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END max_depth=10, max_features=1.0, min_samples_leaf=5, min_samples_split=5, n_estimators=900;, score=0.900 total time=   2.3s
# [CV 2/5] END max_depth=10, max_features=1.0, min_samples_leaf=5, min_samples_split=5, n_estimators=900;, score=0.892 total time=   1.4s
# [CV 3/5] END max_depth=10, max_features=1.0, min_samples_leaf=5, min_samples_split=5, n_estimators=900;, score=0.912 total time=   2.3s
# [CV 4/5] END max_depth=10, max_features=1.0, min_samples_leaf=5, min_samples_split=5, n_estimators=900;, score=0.931 total time=   1.7s
# [CV 5/5] END max_depth=10, max_features=1.0, min_samples_leaf=5, min_samples_split=5, n_estimators=900;, score=0.867 total time=   1.4s
# [CV 1/5] END max_depth=15, max_features=1.0, min_samples_leaf=2, min_samples_split=10, n_estimators=1100;, score=0.908 total time=   1.7s
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 1000,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 1.0,
#  'max_depth': 25}

# %%
y_pred = rf_random.predict(X_test)

# %%
final_df = pd.DataFrame({
    'Actual Value': y_test,
    'Predicted Value': y_pred

})

# %%
final_df
# Out:
#      Actual Value  Predicted Value
# 15      30760.000     35566.317500
# 9       17859.167     17995.976000
# 100      9549.000      9053.935000
# 132     11850.000     13072.721833
# 68      28248.000     29035.630500
# 95       7799.000      7308.939000
# 159      7788.000      7874.593500
# 162      9258.000      8022.930000
# 147     10198.000     10009.220583
# 182      7775.000      8039.265000
# 191     13295.000     14013.878250
# 164      8238.000      8012.965000
# 65      18280.000     14357.280250
# 175      9988.000     10721.441667
# 73      40960.000     40571.441643
# 152      6488.000      6478.009000
# 18       5151.000      6145.889042
# 82      12629.000     14185.236000
# 86       8189.000      8701.433000
# 143      9960.000      9426.374000
# 60       8495.000     10392.433167
# 101     13499.000     15241.295000
# 98       8249.000      7300.902000
# 30       6479.000      6049.481633
# 25       6692.000      7181.714500
# 16      41315.000     35387.975000
# ...

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9551076858869176
